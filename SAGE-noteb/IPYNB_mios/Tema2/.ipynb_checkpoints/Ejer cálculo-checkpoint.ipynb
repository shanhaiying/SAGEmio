# %% [markdown]
# EJERCICIO CÁLCULO

# %%
var('a b')
# Out:
# (a, b)

# %%
def f(x,a,b):
    return x^4 - 6*x^2 + a*x + b

# %%
p=f(x,0,0)
plot(p,(x, -3, 3))
# Out:
# Graphics object consisting of 1 graphics primitive
