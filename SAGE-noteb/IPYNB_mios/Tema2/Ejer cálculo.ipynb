# %% [markdown]
#  EJERCICIO CÁLCULO

# %%
var('a b')
# Out:
# (a, b)

# %%
def f(x,a,b):
    return x^4 - 6*x^2 + a*x + b

# %%
p=f(x,3,4)
plot(p,(x, -2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive
